# %%
from torchtune.data import AlpacaInstructTemplate

sample = {
    "instruction": "Given a news article, predict the stock price changes for the mentioned companies.",
    "input": {
        "news_content": "Lorem ipsum dolor sit amet, consectetur adipiscing elit...",
        "publication_date": "2024-04-18",
        "sentiment": "positive",
        "industry": "Technology",
        "companies": ["Company A", "Company B", "Company Z", "Company 500"],
        "stock_price_changes": {
            "Company A": "increase",
            "Company B": "decrease",
            "Company Z": "unchanged",
            "Company 500": "increase"
        }
    }
}
prompt = AlpacaInstructTemplate.format(sample)
print(prompt)
# Out:
# Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Given a news article, predict the stock price changes for the mentioned companies.
#
# ### Input:
# {'news_content': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit...', 'publication_date': '2024-04-18', 'sentiment': 'positive', 'industry': 'Technology', 'companies': ['Company A', 'Company B', 'Company Z', 'Company 500'], 'stock_price_changes': {'Company A': 'increase', 'Company B': 'decrease', 'Company Z': 'unchanged', 'Company 500': 'increase'}}
#
# ### Response:

# %%
import pandas as pd
from preprocess import preprocess_sample
from custom_preference_dataset import CustomPreferenceDataset
from pprint import pprint

# Load the dataset from a CSV file
file_path = 'dataset.csv'
df = pd.read_csv(file_path)

# Apply preprocessing to each row in the DataFrame
df = df.apply(preprocess_sample, axis=1)

# Initialize the custom dataset with the preprocessed DataFrame
dataset = CustomPreferenceDataset(df)

# Accessing and displaying a sample from the dataset
sample = dataset[20]
pprint(sample)

# print only the attribute fields of json object in sample 
# pprint({k for k, v in sample.items() if k != 'instruction'})
# Out:
# {'date': '2024-05-06',
#  'industry': 'Automotive',
#  'negative_changes': 'Company5 -58.84%, Company7 -69.60%, Company12 -98.80%, '
#                      'Company13 -54.09%, Company16 -35.84%, Company20 -43.75%, '
#                      'Company21 -62.25%, Company25 -16.17%, Company26 -30.53%, '
#                      'Company27 -56.97%, Company30 -31.25%, Company31 -65.29%, '
#                      'Company35 -5.45%, Company36 -32.97%, Company38 -52.20%, '
#                      'Company39 -95.29%, Company47 -54.26%, Company48 -36.06%, '
#                      'Company49 -23.86%, Company51 -83.04%, Company54 -67.86%, '
#                      'Company56 -28.70%, Company57 -74.01%, Company58 -2.14%, '
#                      'Company67 -24.53%, Company68 -91.91%, Company69 -34.63%, '
#                      'Company71 -60.21%, Company72 -68.97%, Company74 -41.80%, '
#                      'Company75 -72.32%, Company77 -72.84%, Company81 -78.91%, '
# ...

# %%
from torchtune.datasets import stack_exchanged_paired_dataset

# Initialize the dataset with the path to the CSV file
file_path = 'dataset.csv'
dataset = stack_exchanged_paired_dataset(file_path)

# Accessing and displaying a sample from the dataset
sample = dataset[20]
pprint(sample)

# %%
from torchtune.data import StackExchangedPairedTemplate

sample = {
    "prompt": "What is the best way to learn Python?",
    "chosen": "The best way to learn Python is to start with the basics and practice regularly.",
    "rejected": "I think the best way to learn Python is to take an online course and build projects."
}

p = StackExchangedPairedTemplate.format(sample)
print(p)
# Out:
# Question: What is the best way to learn Python?
#
# Answer:
