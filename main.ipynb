# %%
import torch
import pandas as pd
import yfinance as yf
import json
from tqdm import tqdm
import random

device = ("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
device
# Out:
# 'mps'

# %%
news_data_file_path = 'stock-news-dataset-sample.txt'

sp500_data = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
sp500_tickers = sp500_data['Symbol'].tolist()

columns = ["timestamp", "url", "title", "description"] + sp500_tickers
column_idx = {col: i for i, col in enumerate(columns)}

HOUR = 60 * 60

# %%
dataset = []
errors = []
pbar = tqdm()
limit_rem = 1000

with open(news_data_file_path, "r") as f:
    l = 0
    while (line := f.readline()):
    # for line in tqdm(f):
        try:
            story = json.loads(line)
            row = [None] * len(columns)
            timestamp = story["unix_timestamp"] - 60*60*16
            row[column_idx["timestamp"]] = timestamp
            row[column_idx["url"]] = story["url"]
            row[column_idx["title"]] = story["title"]
            row[column_idx["description"]] = story["description"]

            tickers = [T for t in story.get("tickers_direct", []) + story.get("tickers_indirect", []) if (T := t.upper()) in sp500_tickers]

            for ticker in tickers:
                yfTicker = yf.Ticker(ticker)
                hist = yfTicker.history(start=timestamp-24*5*HOUR, end=timestamp+24*5*HOUR, interval='1h')
                hist_times = hist.index.values.astype('int') // 1e9

                i = 0
                while i < len(hist_times) and hist_times[i+1] < timestamp:
                    i += 1
                init_idx = i
                
                i += 1
                while i < len(hist_times) and hist_times[i] - 3*HOUR  < timestamp:
                    i += 1
                final_idx = i

                initial_price = hist.iloc[init_idx]["Open"]
                final_price = hist.iloc[final_idx]["Close"]
                row[column_idx[ticker]] = (final_price - initial_price) / initial_price * 100

            dataset.append(row)

        except Exception as e:
            errors.append(e)

        # tqdm stuff to keep track of progress
        
        l += (jump := random.randint(1, 10))
        pbar.update(jump)

        if limit_rem is not None:
            limit_rem -= 1
            if limit_rem <= 0:
                break

pbar.close()
print(f"Errors: {errors}")
    
df = pd.DataFrame(dataset, columns=columns)
df.to_csv("dataset-one-hot-enc.csv", index=False)
df
# Out:
# 2223it [00:08, 258.82it/s]
# Errors: [KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description'), KeyError('description')]
#       timestamp                                                url  \
# 0    1679065123  https://www.etfdailynews.com/2023/03/18/adapti...
# 1    1679065121  https://www.etfdailynews.com/2023/03/18/adicet...
# 2    1679065121  https://www.tickerreport.com/banking-finance/1...
# 3    1679065121  https://www.tickerreport.com/banking-finance/1...
# 4    1679065121  https://www.etfdailynews.com/2023/03/18/arbutu...
# ..          ...                                                ...
# 380  1679060058  https://leadership.ng/terra-unveils-shrimp-sea...
# 381  1679060034  https://www.teamblind.com/post/integration-of-...
# 382  1679060034  https://www.teamblind.com/post/is-amazon-going...
# 383  1679060034  https://www.teamblind.com/post/good-time-to-bu...
# 384  1679060034  https://www.teamblind.com/post/l5-google-swe-l...
#
#                                                  title  \
# 0    Adaptimmune Therapeutics (NASDAQ:ADAP) Coverag...
# 1    Adicet Bio (NASDAQ:ACET) Rating Reiterated by ...
# 2    Abeona Therapeutics (NASDAQ:ABEO) Earns Hold R...
# 3    Graybug Vision Stock Set to Reverse Split on M...
# 4    Arbutus Biopharma (NASDAQ:ABUS) Coverage Initi...
# ..                                                 ...
# 380                Terra Unveils Shrimp Seasoning Cube
# 381  Integration of ChatGPT with Microsoft’s Azure ...
# 382                 Is Amazon going to do more layoff?
# 383              Good time to buy first republic bank?
# 384               L5 Google SWE looking to maximize TC
#
#                                            description   MMM   AOS   ABT  \
# 0    Equities research analysts at StockNews.com st...  None  None  None
# 1    Adicet Bio (NASDAQ:ACET – Get Rating)‘s stock ...  None  None  None
# 2    Equities research analysts at StockNews.com be...  None  None  None
# 3    Graybug Vision, Inc. (NASDAQ:GRAY – Get Rating...  None  None  None
# 4    Equities researchers at StockNews.com began co...  None  None  None
# ..                                                 ...   ...   ...   ...
# 380  Tropical General Investments (TGI) Group has u...  None  None  None
# 381  Do you think that Azure's implementation of a ...  None  None  None
# 382  After meta second round of layoff, the next qu...  None  None  None
# 383                                                     None  None  None
# 384  Looking to jump to other places as a SWE. Gene...  None  None  None
#
#      ABBV   ACN  ADBE  ...   WMB   WTW   GWW  WYNN XEL   XYL   YUM  ZBRA  \
# 0    None  None  None  ...  None  None  None  None NaN  None  None  None
# 1    None  None  None  ...  None  None  None  None NaN  None  None  None
# 2    None  None  None  ...  None  None  None  None NaN  None  None  None
# 3    None  None  None  ...  None  None  None  None NaN  None  None  None
# 4    None  None  None  ...  None  None  None  None NaN  None  None  None
# ..    ...   ...   ...  ...   ...   ...   ...   ...  ..   ...   ...   ...
# 380  None  None  None  ...  None  None  None  None NaN  None  None  None
# 381  None  None  None  ...  None  None  None  None NaN  None  None  None
# 382  None  None  None  ...  None  None  None  None NaN  None  None  None
# 383  None  None  None  ...  None  None  None  None NaN  None  None  None
# 384  None  None  None  ...  None  None  None  None NaN  None  None  None
#
#       ZBH   ZTS
# 0    None  None
# 1    None  None
# 2    None  None
# 3    None  None
# 4    None  None
# ..    ...   ...
# 380  None  None
# 381  None  None
# 382  None  None
# 383  None  None
# 384  None  None
#
# [385 rows x 507 columns]

# %%
yf.Ticker('MSFT').history(start=1700811374, end=1700836574, interval='1h')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[183], line 1
# ----> 1 yf.Ticker('MSFT').history(start=1700811374, end=1700836574, interval='1h')
#
# File ~/Code/llm-stock-predictor/venv/lib/python3.12/site-packages/yfinance/utils.py:103, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     100 logger.debug(f'Entering {func.__name__}()')
#     102 with IndentationContext():
# --> 103     result = func(*args, **kwargs)
#     105 logger.debug(f'Exiting {func.__name__}()')
#     106 return result
#
# File ~/Code/llm-stock-predictor/venv/lib/python3.12/site-packages/yfinance/base.py:77, in TickerBase.history(self, *args, **kwargs)
#      75 @utils.log_indent_decorator
#      76 def history(self, *args, **kwargs) -> pd.DataFrame:
# ---> 77     return self._lazy_load_price_history().history(*args, **kwargs)
#
# File ~/Code/llm-stock-predictor/venv/lib/python3.12/site-packages/yfinance/utils.py:103, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     100 logger.debug(f'Entering {func.__name__}()')
#     102 with IndentationContext():
# --> 103     result = func(*args, **kwargs)
#     105 logger.debug(f'Exiting {func.__name__}()')
#     106 return result
#
# File ~/Code/llm-stock-predictor/venv/lib/python3.12/site-packages/yfinance/scrapers/history.py:226, in PriceHistory.history(self, period, interval, start, end, prepost, actions, auto_adjust, back_adjust, repair, keepna, proxy, rounding, timeout, raise_errors)
#     224         self._reconstruct_start_interval = None
#     225     return shared._DFS[self.ticker]
# --> 226 logger.debug(f'{self.ticker}: yfinance received OHLC data: {quotes.index[0]} -> {quotes.index[-1]}')
#     228 # 2) fix weired bug with Yahoo! - returning 60m for 30m bars
#     229 if interval.lower() == "30m":
#
# File ~/Code/llm-stock-predictor/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:5389, in Index.__getitem__(self, key)
#    5386 if is_integer(key) or is_float(key):
#    5387     # GH#44051 exclude bool, which would return a 2d ndarray
#    5388     key = com.cast_scalar_indexer(key)
# -> 5389     return getitem(key)
#    5391 if isinstance(key, slice):
#    5392     # This case is separated from the conditional above to avoid
#    5393     # pessimization com.is_bool_indexer and ndim checks.
#    5394     return self._getitem_slice(key)
#
# File ~/Code/llm-stock-predictor/venv/lib/python3.12/site-packages/pandas/core/arrays/datetimelike.py:381, in DatetimeLikeArrayMixin.__getitem__(self, key)
#     374 """
#     375 This getitem defers to the underlying array, which by-definition can
#     376 only handle list-likes, slices, and integer scalars
#     377 """
#     378 # Use cast as we know we will get back a DatetimeLikeArray or DTScalar,
#     379 # but skip evaluating the Union at runtime for performance
#     380 # (see https://github.com/pandas-dev/pandas/pull/44624)
# --> 381 result = cast("Union[Self, DTScalarOrNaT]", super().__getitem__(key))
#     382 if lib.is_scalar(result):
#     383     return result
#
# File ~/Code/llm-stock-predictor/venv/lib/python3.12/site-packages/pandas/core/arrays/_mixins.py:284, in NDArrayBackedExtensionArray.__getitem__(self, key)
#     278 def __getitem__(
#     279     self,
#     280     key: PositionalIndexer2D,
#     281 ) -> Self | Any:
#     282     if lib.is_integer(key):
#     283         # fast-path
# --> 284         result = self._ndarray[key]
#     285         if self.ndim == 1:
#     286             return self._box_func(result)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# previously used code

            # while timestamp > (init_timestamp := hist.index.values[0].astype('int') // 1e9):
            #     init_timestamp += HOUR
            #     hist = yfTicker.history(start=init_timestamp-24*5*HOUR, end=datetime.fromtimestamp(init_timestamp+24*5*HOUR), interval='1h')

            # start = timestamp - 60*60*2
            # end = timestamp + 60*60*6
            # hist = yfTicker.history(start=start, end=end, interval='1h')

            # for i in range(24*5):
            #     # print(datetime.datetime.fromtimestamp(hist.index.values[0].astype('int') // 1e9), datetime.datetime.fromtimestamp(timestamp))
            #     # print(hist.index.values[0].astype('int') // 1e9, timestamp)
            #     if len(hist) == 0 or hist.index.values[0].astype('int') // 1e9 > timestamp:
            #         start -= 60*60
            #         hist = yfTicker.history(start=start, end=end, interval='1h')
            #         # print(datetime.fromtimestamp(start), hist.index[0] if len(hist) > 0 else None)
            #     else:
            #         break

            # for i in range(24*4):
            #     if len(hist) < 2:
            #         end += 60*60
            #         # print(timestamp, ticker, start, end)
            #         hist = yfTicker.history(start=start, end=end, interval='1h')
            #     else:
            #         break

            # initial_price = hist["Open"].values[0]
            # final_price = hist["Close"].values[-1]
