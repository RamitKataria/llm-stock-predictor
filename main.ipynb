# %%
import torch
import pandas as pd
import yfinance as yf
import json
from tqdm import tqdm
import random

device = ("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
device
# Out:
# 'cuda'

# %%
news_data_file_path = 'TickerTick-stock-news-dataset.2023-11-23.json'

sp500_data = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
sp500_tickers = sp500_data['Symbol'].tolist()

columns = ["timestamp", "url", "title", "description"] + sp500_tickers
column_idx = {col: i for i, col in enumerate(columns)}

HOUR = 60 * 60

# %%
dataset = []
errors = []
pbar = tqdm()
limit_rem = 10000

with open(news_data_file_path, "r") as f:
    l = 0
    while (line := f.readline()):
    # for line in tqdm(f):
        try:
            story = json.loads(line)
            if "description" not in story:
                continue

            row = [None] * len(columns)
            timestamp = story["unix_timestamp"] - 60*60*16
            row[column_idx["timestamp"]] = timestamp
            row[column_idx["url"]] = story["url"]
            row[column_idx["title"]] = story["title"]
            row[column_idx["description"]] = story["description"]

            tickers = [T for t in story.get("tickers_direct", []) + story.get("tickers_indirect", []) if (T := t.upper()) in sp500_tickers]

            if len(tickers) == 0:
                continue

            for ticker in tickers:
                yfTicker = yf.Ticker(ticker)
                hist = yfTicker.history(start=timestamp-24*2*HOUR, end=timestamp+24*2*HOUR, interval='1h', raise_errors=True)
                if len(hist) < 12:
                    hist = yfTicker.history(start=timestamp-24*7*HOUR, end=timestamp+24*7*HOUR, interval='1h', raise_errors=True)
                hist_times = hist.index.values.astype('int64') // 1e9

                i = 0
                while i+2 < len(hist_times) and hist_times[i+1] < timestamp:
                    i += 1
                init_idx = i
                
                i += 1
                while i < len(hist_times) and hist_times[i] - 3*HOUR  < timestamp:
                    i += 1
                final_idx = i

                init_price = hist.iloc[init_idx]["Open"]
                final_price = hist.iloc[final_idx]["Close"]
                change_pct = (final_price - init_price) / init_price * 100
                row[column_idx[ticker]] = change_pct

            dataset.append(row)

        except Exception as e:
            errors.append((e, story["id"]))

        # tqdm stuff to keep track of progress
        l += (jump := random.randint(1, 90))
        pbar.update(jump)

        if limit_rem is not None:
            limit_rem -= 1
            if limit_rem <= 0:
                break

pbar.close()
print(f"{len(errors)} errors: {errors}")
    
df = pd.DataFrame(dataset, columns=columns)
df.to_csv("dataset-one-hot-enc.csv", index=False)
df
# Out:
# 0it [00:00, ?it/s]
# 460000it [07:32, 1017.61it/s]
# 36 errors: [(Exception('BRK.B: No timezone found, symbol may be delisted'), '-2146268629891649901'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-2876896092783107358'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-5602237677975798316'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '8253319829633350123'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-6056503350793612874'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '8058031600686423630'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '826602545318281906'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-1801203470565253377'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-4811615795256040667'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-7972420577751134448'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-3466383762346591439'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '6656700047717426109'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-2660557431756362884'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-7130603208876931010'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-2392678894444649970'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-435954749869782563'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-368262659763523121'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '3431660013378674216'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '3328724122741270917'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '3259152890420939044'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-1668278647890434351'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-6821279396351070481'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-8597191897628358567'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-8042919520064372438'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-1708940655633185759'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '4930834862936402082'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-7248437315838153652'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-2308003950346832498'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-6907859621506516685'), (Exception('BF.B: No price data found, symbol may be delisted (1h 1700401978 -> 1700747578)'), '5701848445030730441'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '4085288071331321920'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '8435183367225957820'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '-6478464478510242702'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '2445593952606709964'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '5045646628918582779'), (Exception('BRK.B: No timezone found, symbol may be delisted'), '1059209333965279939')]
#        timestamp                                                url  \
# 0     1700761052  https://www.marketbeat.com/instant-alerts/nyse...
# 1     1700760974  https://www.openpr.com/news/3301861/images-con...
# 2     1700760916  https://www.androidpolice.com/linkedin-ai-prof...
# 3     1700760858  https://retailtimes.co.uk/jd-announces-its-hug...
# 4     1700760780  https://www.globenewswire.com/en/news-release/...
# ...          ...                                                ...
# 9959  1700546344  https://news.google.com/rss/articles/CBMicGh0d...
# 9960  1700546340  https://finance.yahoo.com/m/b02bc82e-703d-39ba...
# 9961  1700546339  https://www.mercurynews.com/2023/11/21/police-...
# 9962  1700546282  https://www.marketscreener.com/quote/stock/AUT...
# 9963  1700546280  https://finance.yahoo.com/m/9f8d1621-4397-3750...
#
#                                                   title  \
# 0     Principal Financial Group Inc. Lowers Stock Po...
# 1     Images Content Moderation Solution Market Size...
# 2           LinkedIn: How to create an AI profile photo
# 3     JD announces its huge Black Friday Sale with u...
# 4     Commercial Aircraft Global Market Outlook 2023...
# ...                                                 ...
# 9959  Nvidia Earnings Soar Past Analyst Predictions ...
# 9960              Nvidia Calls the Shots After the Bell
# 9961  Police shoot Oakland man who allegedly tried t...
# 9962  Autodesk Raises Full-Year Guidance After 3Q Re...
# 9963  Nvidia Crushes Earnings on Soaring AI Chip Dem...
#
#                                             description   MMM   AOS  ABT  \
# 0     Principal Financial Group Inc. trimmed its sta...  None  None  NaN
# 1     Images Content Moderation Solution replace wit...  None  None  NaN
# 2     A professional photo is essential for job hunt...  None  None  NaN
# 3     Retail Times publishes international & UK reta...  None  None  NaN
# 4     Dublin, Nov. 24, 2023 (GLOBE NEWSWIRE) -- The ...  None  None  NaN
# ...                                                 ...   ...   ...  ...
# 9959  Nvidia Earnings Soar Past Analyst Predictions ...  None  None  NaN
# 9960  Response to the quarterly report is likely to ...  None  None  NaN
# 9961  The incident happened Sunday morning at a Best...  None  None  NaN
# 9962  (marketscreener.com) By Ben Glickman Autodesk ...  None  None  NaN
# 9963  Nvidia’s revenue was up 206% in its latest qua...  None  None  NaN
#
#       ABBV  ACN  ADBE  ...  WMB  WTW  GWW  WYNN XEL  XYL  YUM  ZBRA  ZBH  ZTS
# 0      NaN  NaN   NaN  ...  NaN  NaN  NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN
# 1      NaN  NaN   NaN  ...  NaN  NaN  NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN
# 2      NaN  NaN   NaN  ...  NaN  NaN  NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN
# 3      NaN  NaN   NaN  ...  NaN  NaN  NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN
# 4      NaN  NaN   NaN  ...  NaN  NaN  NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN
# ...    ...  ...   ...  ...  ...  ...  ...   ...  ..  ...  ...   ...  ...  ...
# 9959   NaN  NaN   NaN  ...  NaN  NaN  NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN
# 9960   NaN  NaN   NaN  ...  NaN  NaN  NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN
# 9961   NaN  NaN   NaN  ...  NaN  NaN  NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN
# 9962   NaN  NaN   NaN  ...  NaN  NaN  NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN
# 9963   NaN  NaN   NaN  ...  NaN  NaN  NaN   NaN NaN  NaN  NaN   NaN  NaN  NaN
#
# [9964 rows x 507 columns]
